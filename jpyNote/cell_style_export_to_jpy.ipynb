# %%
def rectangle(width, height):
    return width * height

# %%
print('Test run')
# Out:
# Test run

# %%
rectangle(4, 5)
# Out:
# 20

# %% [markdown]
#  # tips and tricks
#  ## visual studio code
#  ### editor
#  * visual studio code
#  * sublime
#  * vim
